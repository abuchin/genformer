# %%
import time
import os
import subprocess
import sys
sys.path.insert(0,'..')
import re
import argparse
import collections
import gzip
import math
import shutil
import matplotlib.pyplot as plt
import wandb
import numpy as np
import time
from datetime import datetime
import random

import seaborn as sns
# %matplotlib inline
import logging
from silence_tensorflow import silence_tensorflow
#silence_tensorflow()
os.environ['TPU_LOAD_LIBRARY']='0'
os.environ['TF_ENABLE_EAGER_CLIENT_STREAMING_ENQUEUE']='False'
import tensorflow as tf


import tensorflow.experimental.numpy as tnp
import tensorflow_addons as tfa
from tensorflow import strings as tfs
from tensorflow.keras import mixed_precision
from scipy.stats.stats import pearsonr  
from scipy.stats.stats import spearmanr  
## custom modules
import src.aformer_atac as aformer
#import src.aformer_TF as aformer
from src.layers.layers import *
import src.metrics as metrics
from src.optimizers import *
import src.schedulers as schedulers
import src.utils as utils

import training_utils_atac as training_utils


from scipy import stats
# Out:
# 2023-04-27 19:03:04.943262: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 19:03:05.109254: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2023-04-27 19:03:05.109289: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2023-04-27 19:03:06.022447: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 19:03:06.022569: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2023-04-27 19:03:06.022583: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.

# %%
resolver = tf.distribute.cluster_resolver.TPUClusterResolver(tpu='node-5')
tf.config.experimental_connect_to_cluster(resolver)
tf.tpu.experimental.initialize_tpu_system(resolver)
strategy = tf.distribute.TPUStrategy(resolver)

with strategy.scope():
    options = tf.data.Options()
    options.experimental_distribute.auto_shard_policy = tf.data.experimental.AutoShardPolicy.FILE
    options.deterministic=False
    #options.experimental_threading.max_intra_op_parallelism = 1
    mixed_precision.set_global_policy('mixed_bfloat16')
    tf.config.optimizer.set_jit(True)
    #options.num_devices = 64

    BATCH_SIZE_PER_REPLICA = 1
    NUM_REPLICAS = strategy.num_replicas_in_sync
    GLOBAL_BATCH_SIZE = BATCH_SIZE_PER_REPLICA * NUM_REPLICAS
# Out:
# 2023-04-27 19:03:07.501944: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2023-04-27 19:03:07.502000: W tensorflow/compiler/xla/stream_executor/cuda/cuda_driver.cc:265] failed call to cuInit: UNKNOWN ERROR (303)
# 2023-04-27 19:03:07.502024: I tensorflow/compiler/xla/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tpu-genformer-v2-6): /proc/driver/nvidia/version does not exist
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# 2023-04-27 19:03:07.876275: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-27 19:03:07.898765: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:447] Started server with target: grpc://localhost:39055
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: node-5
# INFO:tensorflow:Initializing the TPU system: node-5
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 0, 0)

# %%
with strategy.scope():

    model = aformer.aformer(kernel_transformation='relu_kernel_transformation',
                            dropout_rate=0.30,
                            pointwise_dropout_rate=0.10,
                            input_length=262144,
                            output_length=2048,
                            final_output_length=1536,
                            num_heads=8,
                            numerical_stabilizer=0.0000001,
                            nb_random_features=256,
                            max_seq_length=2048,
                            rel_pos_bins=2048,
                            norm=True,
                            BN_momentum=0.90,
                            use_rot_emb = True,
                            use_mask_pos = False,
                            normalize = True,
                            num_transformer_layers=6,
                            inits_type="enformer_performer",
                            load_init=False,
                            stable_variant=False,
                            freeze_conv_layers=False,
                            filter_list_seq=[768,896,1024,1152,1280,1536],
                            filter_list_atac=[32,64],
                            output_heads=["human"],
                            learnable_PE=True)


    test = tf.ones((1,262144,4)),tf.ones((1,65536,1))#,tf.ones((1,1,1536))
    model(test,training=False)
    print('ran test input')
    #model.load_weights("gs://picard-testing-176520/genformer_atac_pretrain/models/aformer_hg_mm_rm_rat_262k_load-True_LR-0.01_T-6_D-0.3_2023-04-18_12:37:42/iteration_24/saved_model")
    #model.load_weights("gs://picard-testing-176520/genformer_atac_pretrain/models/aformer_hg_262k_load-True_LR-0.01_T-7_D-0.3_2023-04-13_15:39:43/final/saved_model")
    model.load_weights("gs://picard-testing-176520/genformer_atac_pretrain/models/aformer_hg_262k_load-True_LR-0.01_T-6_D-0.3_2023-04-26_00:40:44/iteration_84/saved_model")
    print('loaded weights')
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/initializers/initializers_v2.py:121: UserWarning: The initializer RandomUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   f"The initializer {self.__class__.__name__} is unseeded "
# ran test input
# loaded weights

# %%
def predict_on_batch(model, inputs):
    return model.predict_on_batch(inputs)

# %%
def one_hot(sequence):
    '''
    convert input string tensor to one hot encoded
    will replace all N character with 0 0 0 0
    '''
    vocabulary = tf.constant(['A', 'C', 'G', 'T'])
    mapping = tf.constant([0, 1, 2, 3])

    init = tf.lookup.KeyValueTensorInitializer(keys=vocabulary,
                                               values=mapping)
    table = tf.lookup.StaticHashTable(init, default_value=0)

    input_characters = tfs.upper(tfs.unicode_split(sequence, 'UTF-8'))

    out = tf.one_hot(table.lookup(input_characters), 
                      depth = 4, 
                      dtype=tf.float32)
    return out


g=tf.random.Generator.from_seed(datetime.now().timestamp())
def deserialize_val(serialized_example,
                   input_length,
                   max_shift,
                   output_length_ATAC,
                   output_length,
                   crop_size,
                   output_res,
                   log_atac,
                   g):
    """Deserialize bytes stored in TFRecordFile."""
    ## parse out feature map
    feature_map = {
        'sequence': tf.io.FixedLenFeature([], tf.string),
        'atac': tf.io.FixedLenFeature([], tf.string),
        'tss_tokens': tf.io.FixedLenFeature([], tf.string),
        'peaks': tf.io.FixedLenFeature([], tf.string)
    }
    ### stochastic sequence shift and gaussian noise

    seq_shift=5
    stupid_random_seed = g.uniform([], 0, 10000000,dtype=tf.int32)
    input_seq_length = input_length + max_shift
    
    ## now parse out the actual data
    data = tf.io.parse_example(serialized_example, feature_map)
    sequence = one_hot(tf.strings.substr(data['sequence'],
                                 seq_shift,input_length))
    atac = tf.ensure_shape(tf.io.parse_tensor(data['atac'],
                                              out_type=tf.float32),
                           [output_length_ATAC,1])
    peaks = tf.ensure_shape(tf.io.parse_tensor(data['peaks'],
                                              out_type=tf.int32),
                           [output_length])
    peaks_crop = tf.slice(tf.expand_dims(peaks,axis=1),
                     [crop_size,0],
                     [output_length-2*crop_size,-1])
    
    atac_target = atac ## store the target

    masked_atac = atac
    
    if log_atac: 
        masked_atac = tf.math.log1p(masked_atac)
        
    diff = tf.math.sqrt(tf.nn.relu(masked_atac - 100.0 * tf.ones(masked_atac.shape)))
    masked_atac = tf.clip_by_value(masked_atac, clip_value_min=0.0, clip_value_max=100.0) + diff
        
    atac_out = tf.reduce_sum(tf.reshape(atac_target, [-1,32]),axis=1,keepdims=True)

    atac_out = tf.cast(tf.cast(atac_out,dtype=tf.float16),dtype=tf.float32) ### round to be consistent with Enformer
    diff = tf.math.sqrt(tf.nn.relu(atac_out - 2500.0 * tf.ones(atac_out.shape)))
    atac_out = tf.clip_by_value(atac_out, clip_value_min=0.0, clip_value_max=2500.0) + diff
    atac_out = tf.slice(atac_out,
                        [crop_size,0],
                        [output_length-2*crop_size,-1])

        
    tss_tokens = tf.ensure_shape(tf.io.parse_tensor(data['tss_tokens'],
                                              out_type=tf.int32),
                           [output_length-2*crop_size])
    tss_tokens=tf.expand_dims(tss_tokens,axis=1)
        
        
    return {'sequence': tf.ensure_shape(sequence,
                                        [input_length,4]),
            'atac': tf.ensure_shape(masked_atac,
                                    [output_length_ATAC,1]),
            'tss_tokens': tf.ensure_shape(tss_tokens,
                                      [output_length-crop_size*2,1]),
            'peaks': tf.ensure_shape(peaks_crop,
                                      [output_length-crop_size*2,1]),
            'target': tf.ensure_shape(atac_out,
                                      [output_length-crop_size*2,1])}

# %%
list_files = (tf.io.gfile.glob(os.path.join("gs://picard-testing-176520/genformer_atac_pretrain/262k/genformer_atac_pretrain_globalacc_conv_rpgc_SINGLE_embeddings",
                                            "*CD69_promoter.tfr")))



preds_all=[]
peaks_pred_all=[]
embeddings_all=[]
out_att_all=[]
att_matrices_all=[]

for file in list_files[:277]:
    g = tf.random.Generator.from_seed(datetime.now().timestamp())
    dataset = tf.data.TFRecordDataset(file,
                                      compression_type='ZLIB',
                                      num_parallel_reads=4)
    dataset = dataset.map(lambda record: deserialize_val(record,
                                                         262144,
                                                         10,
                                                             65536,
                                                         2048,
                                                         256,
                                                         128,
                                                            True,g),
                          deterministic=False,
                          num_parallel_calls=4)
    dataset=dataset.batch(1)
    iter_test = iter(dataset)
    test = next(iter_test)
    inputs = test['sequence'], \
                test['atac']#, \

    pred,peaks_pred,embedding,out_att,att_matrices = predict_on_batch(model,inputs)
    
    preds_all.append(pred)
    peaks_pred_all.append(peaks_pred)
    embeddings_all.append(embedding)
    out_att_all.append(out_att)
    att_matrices_all.append(att_matrices)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089
# WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/autograph/pyct/static_analysis/liveness.py:83: Analyzer.lamba_check (from tensorflow.python.autograph.pyct.static_analysis.liveness) is deprecated and will be removed after 2023-09-23.
# Instructions for updating:
# Lambda fuctions will be no more assumed to be used in the statement where they are used, or at least in the same block. https://github.com/tensorflow/tensorflow/issues/56089

# %%
att_out_all = []
embeddings_out_all=[]
file_names_all=[]
for k,file in enumerate(list_files):
    filename = file.split('/')[-1].split('.chr12')[0]
    
    att_out = np.mean((out_att_all[k].numpy()[0,:,:])[1022:1025,:],axis=0)
    embeddings_out = np.mean((embeddings_all[k].numpy()[0,:,:])[766:769,:],axis=0)
    np.savetxt('att_out/' + filename + '.att_out.txt', att_out)
    np.savetxt('embeddings/' + filename + '.embeddings.txt',embeddings_out)
    embeddings_out_all.append(embeddings_out)
    att_out_all.append(att_out)
    file_names_all.append(filename)

# %%
att_out_all_np = np.array(att_out_all)
embeddings_out_all_np = np.array(embeddings_out_all)

# %%
"""
idx_list=[]
for idx,k in enumerate(file_names_all):
    substring_list = ['Tcell','T_cell', 'B_cell', 'Bcell', 'NKcell', 'NK_cell',
                      'CD8', 'CD4', 'K562', 'AML', 'dendritic', 'LCL', 'LMPP',
                      'MPP','MEP','Mono','NKcell']
    if any(substring in k for substring in substring_list):
        idx_list.append(idx)
"""
# Out:
# "\nidx_list=[]\nfor idx,k in enumerate(file_names_all):\n    substring_list = ['Tcell','T_cell', 'B_cell', 'Bcell', 'NKcell', 'NK_cell',\n                      'CD8', 'CD4', 'K562', 'AML', 'dendritic', 'LCL', 'LMPP',\n                      'MPP','MEP','Mono','NKcell']\n    if any(substring in k for substring in substring_list):\n        idx_list.append(idx)\n"

# %%
df = pd.DataFrame(pd.DataFrame(np.take(embeddings_out_all_np,idx_list,axis=0)))
index = [file_names_all[i] for i in idx_list]
df.index=[file_names_all[i] for i in idx_list]
df=df.astype(float)
df=(df-df.mean())/df.std()
df=df.T

from sklearn.metrics.pairwise import pairwise_distances

# %%
plt.figure(figsize=(15,10))
correlations = pd.DataFrame(pairwise_distances(df,metric='cosine'))
correlations.index=
sns.set(font_scale=0.6)
sns.clustermap(correlations, cmap='RdBu', vmin=-1, vmax=1)
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/matrix.py:654: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)
# /opt/conda/lib/python3.7/site-packages/seaborn/matrix.py:625: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   metric=self.metric)

# %%
df.corr()
# Out:
#                                                     Bcell_1001  CD4Tcell_1022  \
# Bcell_1001                                            1.000000       0.356858
# CD4Tcell_1022                                         0.356858       1.000000
# CD8Tcell_1001                                        -0.698595      -0.811678
# HG_AML_IPSC_U_U                                       0.695721       0.643098
# HG_B_cell_M_22_years                                  0.933042       0.441769
# HG_CD4_positive_AB_T_cell_M_20_years                  0.506339       0.888012
# HG_CD8_positive_AB_T_cell_M_21_years                  0.635161       0.868320
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U          -0.869611      -0.711533
# HG_K562                                               0.157250       0.361183
# HG_T_cell_F_21_years                                  0.611222       0.865444
# HG_T_cell_M_42_years                                 -0.604707      -0.906530
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours        0.897631       0.442066
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...    0.795750       0.755008
# HG_activated_CD4_positive_CD25_positive_AB_regu...   -0.041829      -0.351306
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...    0.800091       0.423835
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...    0.038255      -0.686219
# HG_activated_T_cell_F_33_years_50_U_Interleukin...    0.437771       0.399806
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...   -0.095118      -0.739876
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...   -0.451015      -0.740197
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...    0.763355       0.677705
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...    0.568280       0.933032
# HG_dendritic_cell_100_ng_LPS_2_hours                 -0.618066      -0.903782
# HG_dendritic_cell_100_ng_LPS_30_minutes              -0.787255      -0.799087
# HG_dendritic_cell_100_ng_LPS_6_hours                 -0.778548      -0.808799
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...    0.643069       0.871605
# HG_memory_B_cell_M_40_years                           0.690118       0.849183
# HG_naive_B_cell_F_39_years                            0.665437       0.860035
# HG_naive_B_cell_M_40_years                            0.652758       0.869005
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...    0.659437       0.749053
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...   -0.588616      -0.932895
# HG_stimulated_activated_effector_memory_CD8_pos...   -0.549301      -0.939589
# HG_stimulated_activated_memory_B_cell_M_40_year...   -0.581887      -0.924824
# HG_stimulated_activated_naive_B_cell_F_39_years...    0.181352      -0.737009
# LCL                                                  -0.582700      -0.766137
# LMPP_4983                                            -0.793131      -0.688703
# MEP_2596                                             -0.844420      -0.675628
# MPP_4983                                             -0.858524      -0.671480
# Mono_1001                                            -0.789225      -0.769176
# NKcell_1001                                          -0.485302      -0.882385
#
#                                                     CD8Tcell_1001  \
# Bcell_1001                                              -0.698595
# CD4Tcell_1022                                           -0.811678
# CD8Tcell_1001                                            1.000000
# HG_AML_IPSC_U_U                                         -0.745275
# HG_B_cell_M_22_years                                    -0.803619
# HG_CD4_positive_AB_T_cell_M_20_years                    -0.925073
# HG_CD8_positive_AB_T_cell_M_21_years                    -0.971644
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U              0.893618
# HG_K562                                                 -0.144370
# HG_T_cell_F_21_years                                    -0.962707
# HG_T_cell_M_42_years                                     0.962191
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours          -0.779289
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...      -0.891561
# HG_activated_CD4_positive_CD25_positive_AB_regu...       0.360383
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...      -0.599531
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...       0.530803
# HG_activated_T_cell_F_33_years_50_U_Interleukin...      -0.518062
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...       0.645707
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...       0.775947
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...      -0.771484
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...      -0.871157
# HG_dendritic_cell_100_ng_LPS_2_hours                     0.945371
# HG_dendritic_cell_100_ng_LPS_30_minutes                  0.912042
# HG_dendritic_cell_100_ng_LPS_6_hours                     0.923283
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...      -0.972466
# HG_memory_B_cell_M_40_years                             -0.976305
# HG_naive_B_cell_F_39_years                              -0.962206
# HG_naive_B_cell_M_40_years                              -0.969209
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...      -0.904541
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...       0.944665
# HG_stimulated_activated_effector_memory_CD8_pos...       0.916923
# HG_stimulated_activated_memory_B_cell_M_40_year...       0.903996
# HG_stimulated_activated_naive_B_cell_F_39_years...       0.481644
# LCL                                                      0.944475
# LMPP_4983                                                0.871084
# MEP_2596                                                 0.852171
# MPP_4983                                                 0.904515
# Mono_1001                                                0.866380
# NKcell_1001                                              0.929338
#
#                                                     HG_AML_IPSC_U_U  \
# Bcell_1001                                                 0.695721
# CD4Tcell_1022                                              0.643098
# CD8Tcell_1001                                             -0.745275
# HG_AML_IPSC_U_U                                            1.000000
# HG_B_cell_M_22_years                                       0.668502
# HG_CD4_positive_AB_T_cell_M_20_years                       0.612989
# HG_CD8_positive_AB_T_cell_M_21_years                       0.712526
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U               -0.853019
# HG_K562                                                    0.645292
# HG_T_cell_F_21_years                                       0.717451
# HG_T_cell_M_42_years                                      -0.771625
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours             0.603009
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...         0.877619
# HG_activated_CD4_positive_CD25_positive_AB_regu...        -0.091253
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...         0.806086
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...        -0.145325
# HG_activated_T_cell_F_33_years_50_U_Interleukin...         0.547320
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...        -0.277409
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...        -0.532033
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...         0.903675
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...         0.766787
# HG_dendritic_cell_100_ng_LPS_2_hours                      -0.742050
# HG_dendritic_cell_100_ng_LPS_30_minutes                   -0.865230
# HG_dendritic_cell_100_ng_LPS_6_hours                      -0.866127
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...         0.720964
# HG_memory_B_cell_M_40_years                                0.730619
# HG_naive_B_cell_F_39_years                                 0.786344
# HG_naive_B_cell_M_40_years                                 0.770868
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...         0.646823
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...        -0.768978
# HG_stimulated_activated_effector_memory_CD8_pos...        -0.774955
# HG_stimulated_activated_memory_B_cell_M_40_year...        -0.828516
# HG_stimulated_activated_naive_B_cell_F_39_years...        -0.292403
# LCL                                                       -0.565132
# LMPP_4983                                                 -0.882258
# MEP_2596                                                  -0.885877
# MPP_4983                                                  -0.820784
# Mono_1001                                                 -0.897370
# NKcell_1001                                               -0.605471
#
#                                                     HG_B_cell_M_22_years  \
# Bcell_1001                                                      0.933042
# CD4Tcell_1022                                                   0.441769
# CD8Tcell_1001                                                  -0.803619
# HG_AML_IPSC_U_U                                                 0.668502
# HG_B_cell_M_22_years                                            1.000000
# HG_CD4_positive_AB_T_cell_M_20_years                            0.610166
# HG_CD8_positive_AB_T_cell_M_21_years                            0.734300
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                    -0.864532
# HG_K562                                                         0.102482
# HG_T_cell_F_21_years                                            0.690766
# HG_T_cell_M_42_years                                           -0.700360
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                  0.973877
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...              0.834041
# HG_activated_CD4_positive_CD25_positive_AB_regu...             -0.132752
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...              0.763806
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...             -0.092376
# HG_activated_T_cell_F_33_years_50_U_Interleukin...              0.481384
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...             -0.220709
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...             -0.530698
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...              0.761406
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...              0.595314
# HG_dendritic_cell_100_ng_LPS_2_hours                           -0.695429
# HG_dendritic_cell_100_ng_LPS_30_minutes                        -0.806707
# HG_dendritic_cell_100_ng_LPS_6_hours                           -0.798417
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...              0.716914
# HG_memory_B_cell_M_40_years                                     0.754669
# HG_naive_B_cell_F_39_years                                      0.713092
# HG_naive_B_cell_M_40_years                                      0.712791
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...              0.749142
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...             -0.667058
# HG_stimulated_activated_effector_memory_CD8_pos...             -0.630425
# HG_stimulated_activated_memory_B_cell_M_40_year...             -0.639221
# HG_stimulated_activated_naive_B_cell_F_39_years...              0.075732
# LCL                                                            -0.706945
# LMPP_4983                                                      -0.815563
# MEP_2596                                                       -0.838945
# MPP_4983                                                       -0.882060
# Mono_1001                                                      -0.778249
# NKcell_1001                                                    -0.624605
#
#                                                     HG_CD4_positive_AB_T_cell_M_20_years  \
# Bcell_1001                                                                      0.506339
# CD4Tcell_1022                                                                   0.888012
# CD8Tcell_1001                                                                  -0.925073
# HG_AML_IPSC_U_U                                                                 0.612989
# HG_B_cell_M_22_years                                                            0.610166
# HG_CD4_positive_AB_T_cell_M_20_years                                            1.000000
# HG_CD8_positive_AB_T_cell_M_21_years                                            0.981455
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                    -0.766748
# HG_K562                                                                         0.036377
# HG_T_cell_F_21_years                                                            0.981304
# HG_T_cell_M_42_years                                                           -0.945403
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                  0.588525
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                              0.764174
# HG_activated_CD4_positive_CD25_positive_AB_regu...                             -0.355198
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                              0.379159
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                             -0.693418
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                              0.558324
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                             -0.790790
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                             -0.729594
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                              0.610964
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                              0.895173
# HG_dendritic_cell_100_ng_LPS_2_hours                                           -0.951300
# HG_dendritic_cell_100_ng_LPS_30_minutes                                        -0.840574
# HG_dendritic_cell_100_ng_LPS_6_hours                                           -0.855222
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                              0.973730
# HG_memory_B_cell_M_40_years                                                     0.956767
# HG_naive_B_cell_F_39_years                                                      0.936555
# HG_naive_B_cell_M_40_years                                                      0.945166
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                              0.929813
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                             -0.963149
# HG_stimulated_activated_effector_memory_CD8_pos...                             -0.940543
# HG_stimulated_activated_memory_B_cell_M_40_year...                             -0.924042
# HG_stimulated_activated_naive_B_cell_F_39_years...                             -0.693489
# LCL                                                                            -0.954462
# LMPP_4983                                                                      -0.725532
# MEP_2596                                                                       -0.713147
# MPP_4983                                                                       -0.802276
# Mono_1001                                                                      -0.797189
# NKcell_1001                                                                    -0.935140
#
#                                                     HG_CD8_positive_AB_T_cell_M_21_years  \
# Bcell_1001                                                                      0.635161
# CD4Tcell_1022                                                                   0.868320
# CD8Tcell_1001                                                                  -0.971644
# HG_AML_IPSC_U_U                                                                 0.712526
# HG_B_cell_M_22_years                                                            0.734300
# HG_CD4_positive_AB_T_cell_M_20_years                                            0.981455
# HG_CD8_positive_AB_T_cell_M_21_years                                            1.000000
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                    -0.861048
# HG_K562                                                                         0.111315
# HG_T_cell_F_21_years                                                            0.989682
# HG_T_cell_M_42_years                                                           -0.969668
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                  0.712870
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                              0.862116
# HG_activated_CD4_positive_CD25_positive_AB_regu...                             -0.308397
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                              0.529594
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                             -0.588207
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                              0.599075
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                             -0.701510
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                             -0.732085
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                              0.727701
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                              0.909494
# HG_dendritic_cell_100_ng_LPS_2_hours                                           -0.976107
# HG_dendritic_cell_100_ng_LPS_30_minutes                                        -0.913096
# HG_dendritic_cell_100_ng_LPS_6_hours                                           -0.923862
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                              0.989784
# HG_memory_B_cell_M_40_years                                                     0.981590
# HG_naive_B_cell_F_39_years                                                      0.962812
# HG_naive_B_cell_M_40_years                                                      0.969053
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                              0.954535
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                             -0.978256
# HG_stimulated_activated_effector_memory_CD8_pos...                             -0.950021
# HG_stimulated_activated_memory_B_cell_M_40_year...                             -0.945158
# HG_stimulated_activated_naive_B_cell_F_39_years...                             -0.580408
# LCL                                                                            -0.956684
# LMPP_4983                                                                      -0.827626
# MEP_2596                                                                       -0.817754
# MPP_4983                                                                       -0.889367
# Mono_1001                                                                      -0.871831
# NKcell_1001                                                                    -0.930697
#
#                                                     HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U  \
# Bcell_1001                                                                            -0.869611
# CD4Tcell_1022                                                                         -0.711533
# CD8Tcell_1001                                                                          0.893618
# HG_AML_IPSC_U_U                                                                       -0.853019
# HG_B_cell_M_22_years                                                                  -0.864532
# HG_CD4_positive_AB_T_cell_M_20_years                                                  -0.766748
# HG_CD8_positive_AB_T_cell_M_21_years                                                  -0.861048
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                            1.000000
# HG_K562                                                                               -0.350338
# HG_T_cell_F_21_years                                                                  -0.848176
# HG_T_cell_M_42_years                                                                   0.855381
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                        -0.848863
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                                    -0.969221
# HG_activated_CD4_positive_CD25_positive_AB_regu...                                     0.110267
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                                    -0.846492
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                                     0.202294
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                                    -0.548179
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                                     0.330597
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                                     0.606281
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                                    -0.930312
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                                    -0.864708
# HG_dendritic_cell_100_ng_LPS_2_hours                                                   0.891628
# HG_dendritic_cell_100_ng_LPS_30_minutes                                                0.979438
# HG_dendritic_cell_100_ng_LPS_6_hours                                                   0.975050
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                                    -0.877470
# HG_memory_B_cell_M_40_years                                                           -0.896772
# HG_naive_B_cell_F_39_years                                                            -0.895300
# HG_naive_B_cell_M_40_years                                                            -0.886154
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                                    -0.820574
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                                     0.865976
# HG_stimulated_activated_effector_memory_CD8_pos...                                     0.823302
# HG_stimulated_activated_memory_B_cell_M_40_year...                                     0.864015
# HG_stimulated_activated_naive_B_cell_F_39_years...                                     0.194283
# LCL                                                                                    0.758453
# LMPP_4983                                                                              0.953505
# MEP_2596                                                                               0.977590
# MPP_4983                                                                               0.964428
# Mono_1001                                                                              0.965249
# NKcell_1001                                                                            0.734744
#
#                                                      HG_K562  \
# Bcell_1001                                          0.157250
# CD4Tcell_1022                                       0.361183
# CD8Tcell_1001                                      -0.144370
# HG_AML_IPSC_U_U                                     0.645292
# HG_B_cell_M_22_years                                0.102482
# HG_CD4_positive_AB_T_cell_M_20_years                0.036377
# HG_CD8_positive_AB_T_cell_M_21_years                0.111315
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U        -0.350338
# HG_K562                                             1.000000
# HG_T_cell_F_21_years                                0.123641
# HG_T_cell_M_42_years                               -0.273722
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours      0.071516
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...  0.441366
# HG_activated_CD4_positive_CD25_positive_AB_regu...  0.043946
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...  0.580327
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...  0.114151
# HG_activated_T_cell_F_33_years_50_U_Interleukin...  0.097564
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...  0.091537
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_... -0.186988
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...  0.601800
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...  0.378995
# HG_dendritic_cell_100_ng_LPS_2_hours               -0.218207
# HG_dendritic_cell_100_ng_LPS_30_minutes            -0.372874
# HG_dendritic_cell_100_ng_LPS_6_hours               -0.356563
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...  0.134942
# HG_memory_B_cell_M_40_years                         0.134800
# HG_naive_B_cell_F_39_years                          0.229383
# HG_naive_B_cell_M_40_years                          0.211987
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_... -0.006476
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_... -0.278681
# HG_stimulated_activated_effector_memory_CD8_pos... -0.336938
# HG_stimulated_activated_memory_B_cell_M_40_year... -0.394789
# HG_stimulated_activated_naive_B_cell_F_39_years... -0.091475
# LCL                                                 0.120249
# LMPP_4983                                          -0.413904
# MEP_2596                                           -0.423144
# MPP_4983                                           -0.224946
# Mono_1001                                          -0.447057
# NKcell_1001                                        -0.123172
#
#                                                     HG_T_cell_F_21_years  ...  \
# Bcell_1001                                                      0.611222  ...
# CD4Tcell_1022                                                   0.865444  ...
# CD8Tcell_1001                                                  -0.962707  ...
# HG_AML_IPSC_U_U                                                 0.717451  ...
# HG_B_cell_M_22_years                                            0.690766  ...
# HG_CD4_positive_AB_T_cell_M_20_years                            0.981304  ...
# HG_CD8_positive_AB_T_cell_M_21_years                            0.989682  ...
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                    -0.848176  ...
# HG_K562                                                         0.123641  ...
# HG_T_cell_F_21_years                                            1.000000  ...
# HG_T_cell_M_42_years                                           -0.972959  ...
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                  0.655996  ...
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...              0.840645  ...
# HG_activated_CD4_positive_CD25_positive_AB_regu...             -0.374154  ...
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...              0.503682  ...
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...             -0.625977  ...
# HG_activated_T_cell_F_33_years_50_U_Interleukin...              0.545185  ...
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...             -0.730742  ...
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...             -0.763842  ...
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...              0.711344  ...
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...              0.909753  ...
# HG_dendritic_cell_100_ng_LPS_2_hours                           -0.959776  ...
# HG_dendritic_cell_100_ng_LPS_30_minutes                        -0.898788  ...
# HG_dendritic_cell_100_ng_LPS_6_hours                           -0.910521  ...
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...              0.994914  ...
# HG_memory_B_cell_M_40_years                                     0.987874  ...
# HG_naive_B_cell_F_39_years                                      0.981891  ...
# HG_naive_B_cell_M_40_years                                      0.985166  ...
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...              0.922213  ...
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...             -0.975161  ...
# HG_stimulated_activated_effector_memory_CD8_pos...             -0.956886  ...
# HG_stimulated_activated_memory_B_cell_M_40_year...             -0.945390  ...
# HG_stimulated_activated_naive_B_cell_F_39_years...             -0.617351  ...
# LCL                                                            -0.947006  ...
# LMPP_4983                                                      -0.823477  ...
# MEP_2596                                                       -0.811530  ...
# MPP_4983                                                       -0.878676  ...
# Mono_1001                                                      -0.865702  ...
# NKcell_1001                                                    -0.937652  ...
#
#                                                     HG_naive_thymus_derived_CD8_positive_AB_T_cell_M_42_years  \
# Bcell_1001                                                                                  -0.588616
# CD4Tcell_1022                                                                               -0.932895
# CD8Tcell_1001                                                                                0.944665
# HG_AML_IPSC_U_U                                                                             -0.768978
# HG_B_cell_M_22_years                                                                        -0.667058
# HG_CD4_positive_AB_T_cell_M_20_years                                                        -0.963149
# HG_CD8_positive_AB_T_cell_M_21_years                                                        -0.978256
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                                  0.865976
# HG_K562                                                                                     -0.278681
# HG_T_cell_F_21_years                                                                        -0.975161
# HG_T_cell_M_42_years                                                                         0.979785
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                              -0.645891
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                                          -0.882065
# HG_activated_CD4_positive_CD25_positive_AB_regu...                                           0.301778
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                                          -0.566903
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                                           0.589542
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                                          -0.568840
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                                           0.694824
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                                           0.743219
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                                          -0.779366
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                                          -0.960925
# HG_dendritic_cell_100_ng_LPS_2_hours                                                         0.983519
# HG_dendritic_cell_100_ng_LPS_30_minutes                                                      0.929851
# HG_dendritic_cell_100_ng_LPS_6_hours                                                         0.939292
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                                          -0.977623
# HG_memory_B_cell_M_40_years                                                                 -0.966446
# HG_naive_B_cell_F_39_years                                                                  -0.966112
# HG_naive_B_cell_M_40_years                                                                  -0.969546
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                                          -0.905886
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                                           1.000000
# HG_stimulated_activated_effector_memory_CD8_pos...                                           0.983531
# HG_stimulated_activated_memory_B_cell_M_40_year...                                           0.986616
# HG_stimulated_activated_naive_B_cell_F_39_years...                                           0.627887
# LCL                                                                                          0.895299
# LMPP_4983                                                                                    0.834681
# MEP_2596                                                                                     0.829838
# MPP_4983                                                                                     0.862713
# Mono_1001                                                                                    0.903504
# NKcell_1001                                                                                  0.924255
#
#                                                     HG_stimulated_activated_effector_memory_CD8_positive_AB_T_cell_M_33_years_100_ng_Interleukin_12_subunit_alpha_72_hours_100_ng_Interleukin_12_subunit_beta_72_hours_anti_CD3_and_anti_CD28_coated_beads_72_hours  \
# Bcell_1001                                                                                  -0.549301
# CD4Tcell_1022                                                                               -0.939589
# CD8Tcell_1001                                                                                0.916923
# HG_AML_IPSC_U_U                                                                             -0.774955
# HG_B_cell_M_22_years                                                                        -0.630425
# HG_CD4_positive_AB_T_cell_M_20_years                                                        -0.940543
# HG_CD8_positive_AB_T_cell_M_21_years                                                        -0.950021
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                                  0.823302
# HG_K562                                                                                     -0.336938
# HG_T_cell_F_21_years                                                                        -0.956886
# HG_T_cell_M_42_years                                                                         0.985840
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                              -0.594473
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                                          -0.851164
# HG_activated_CD4_positive_CD25_positive_AB_regu...                                           0.418224
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                                          -0.535518
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                                           0.662601
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                                          -0.474443
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                                           0.752407
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                                           0.816032
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                                          -0.758529
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                                          -0.945656
# HG_dendritic_cell_100_ng_LPS_2_hours                                                         0.940732
# HG_dendritic_cell_100_ng_LPS_30_minutes                                                      0.889561
# HG_dendritic_cell_100_ng_LPS_6_hours                                                         0.898618
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                                          -0.953478
# HG_memory_B_cell_M_40_years                                                                 -0.943299
# HG_naive_B_cell_F_39_years                                                                  -0.954816
# HG_naive_B_cell_M_40_years                                                                  -0.959321
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                                          -0.849104
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                                           0.983531
# HG_stimulated_activated_effector_memory_CD8_pos...                                           1.000000
# HG_stimulated_activated_memory_B_cell_M_40_year...                                           0.979492
# HG_stimulated_activated_naive_B_cell_F_39_years...                                           0.666144
# LCL                                                                                          0.859018
# LMPP_4983                                                                                    0.800032
# MEP_2596                                                                                     0.793169
# MPP_4983                                                                                     0.819327
# Mono_1001                                                                                    0.869250
# NKcell_1001                                                                                  0.939305
#
#                                                     HG_stimulated_activated_memory_B_cell_M_40_years_10_ug_anti_IgM_72_hours_1_ug_anti_CD40_72_hours_100_ng_Interleukin_4_72_hours  \
# Bcell_1001                                                                                  -0.581887
# CD4Tcell_1022                                                                               -0.924824
# CD8Tcell_1001                                                                                0.903996
# HG_AML_IPSC_U_U                                                                             -0.828516
# HG_B_cell_M_22_years                                                                        -0.639221
# HG_CD4_positive_AB_T_cell_M_20_years                                                        -0.924042
# HG_CD8_positive_AB_T_cell_M_21_years                                                        -0.945158
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                                  0.864015
# HG_K562                                                                                     -0.394789
# HG_T_cell_F_21_years                                                                        -0.945390
# HG_T_cell_M_42_years                                                                         0.960961
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                              -0.607122
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                                          -0.885861
# HG_activated_CD4_positive_CD25_positive_AB_regu...                                           0.241671
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                                          -0.603096
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                                           0.531808
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                                          -0.603437
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                                           0.647772
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                                           0.701158
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                                          -0.806964
# ...
# CD4Tcell_1022                                                                               -0.737009
# CD8Tcell_1001                                                                                0.481644
# HG_AML_IPSC_U_U                                                                             -0.292403
# HG_B_cell_M_22_years                                                                         0.075732
# HG_CD4_positive_AB_T_cell_M_20_years                                                        -0.693489
# HG_CD8_positive_AB_T_cell_M_21_years                                                        -0.580408
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U                                                  0.194283
# HG_K562                                                                                     -0.091475
# HG_T_cell_F_21_years                                                                        -0.617351
# HG_T_cell_M_42_years                                                                         0.607679
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours                                               0.130986
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...                                          -0.235378
# HG_activated_CD4_positive_CD25_positive_AB_regu...                                           0.454125
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...                                           0.192858
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...                                           0.838732
# HG_activated_T_cell_F_33_years_50_U_Interleukin...                                          -0.221138
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...                                           0.856146
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...                                           0.554602
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...                                          -0.128477
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...                                          -0.599181
# HG_dendritic_cell_100_ng_LPS_2_hours                                                         0.558280
# HG_dendritic_cell_100_ng_LPS_30_minutes                                                      0.334729
# HG_dendritic_cell_100_ng_LPS_6_hours                                                         0.367573
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...                                          -0.582517
# HG_memory_B_cell_M_40_years                                                                 -0.535508
# HG_naive_B_cell_F_39_years                                                                  -0.566139
# HG_naive_B_cell_M_40_years                                                                  -0.579830
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...                                          -0.465678
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...                                           0.627887
# HG_stimulated_activated_effector_memory_CD8_pos...                                           0.666144
# HG_stimulated_activated_memory_B_cell_M_40_year...                                           0.620997
# HG_stimulated_activated_naive_B_cell_F_39_years...                                           1.000000
# LCL                                                                                          0.577345
# LMPP_4983                                                                                    0.209561
# MEP_2596                                                                                     0.158061
# MPP_4983                                                                                     0.215208
# Mono_1001                                                                                    0.315615
# NKcell_1001                                                                                  0.661270
#
#                                                          LCL  LMPP_4983  \
# Bcell_1001                                         -0.582700  -0.793131
# CD4Tcell_1022                                      -0.766137  -0.688703
# CD8Tcell_1001                                       0.944475   0.871084
# HG_AML_IPSC_U_U                                    -0.565132  -0.882258
# HG_B_cell_M_22_years                               -0.706945  -0.815563
# HG_CD4_positive_AB_T_cell_M_20_years               -0.954462  -0.725532
# HG_CD8_positive_AB_T_cell_M_21_years               -0.956684  -0.827626
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U         0.758453   0.953505
# HG_K562                                             0.120249  -0.413904
# HG_T_cell_F_21_years                               -0.947006  -0.823477
# HG_T_cell_M_42_years                                0.897055   0.843083
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours     -0.675125  -0.796845
# HG_activated_CD4_positive_AB_T_cell_M_20_years_... -0.731733  -0.968571
# HG_activated_CD4_positive_CD25_positive_AB_regu...  0.392021   0.126135
# HG_activated_CD8_positive_AB_T_cell_M_21_years_... -0.355718  -0.868126
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...  0.642956   0.180873
# HG_activated_T_cell_F_33_years_50_U_Interleukin... -0.510984  -0.536099
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...  0.745521   0.281457
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...  0.729545   0.577541
# HG_activated_naive_CD8_positive_AB_T_cell_nucle... -0.563038  -0.951023
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y... -0.795325  -0.800407
# HG_dendritic_cell_100_ng_LPS_2_hours                0.901061   0.850320
# HG_dendritic_cell_100_ng_LPS_30_minutes             0.793573   0.939217
# HG_dendritic_cell_100_ng_LPS_6_hours                0.812215   0.932156
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_... -0.945372  -0.839961
# HG_memory_B_cell_M_40_years                        -0.943956  -0.853407
# HG_naive_B_cell_F_39_years                         -0.907502  -0.874319
# HG_naive_B_cell_M_40_years                         -0.919802  -0.864111
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_... -0.915668  -0.759771
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...  0.895299   0.834681
# HG_stimulated_activated_effector_memory_CD8_pos...  0.859018   0.800032
# HG_stimulated_activated_memory_B_cell_M_40_year...  0.828804   0.838377
# HG_stimulated_activated_naive_B_cell_F_39_years...  0.577345   0.209561
# LCL                                                 1.000000   0.711975
# LMPP_4983                                           0.711975   1.000000
# MEP_2596                                            0.690724   0.988051
# MPP_4983                                            0.809055   0.954578
# Mono_1001                                           0.733551   0.927652
# NKcell_1001                                         0.917663   0.717897
#
#                                                     MEP_2596  MPP_4983  \
# Bcell_1001                                         -0.844420 -0.858524
# CD4Tcell_1022                                      -0.675628 -0.671480
# CD8Tcell_1001                                       0.852171  0.904515
# HG_AML_IPSC_U_U                                    -0.885877 -0.820784
# HG_B_cell_M_22_years                               -0.838945 -0.882060
# HG_CD4_positive_AB_T_cell_M_20_years               -0.713147 -0.802276
# HG_CD8_positive_AB_T_cell_M_21_years               -0.817754 -0.889367
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U         0.977590  0.964428
# HG_K562                                            -0.423144 -0.224946
# HG_T_cell_F_21_years                               -0.811530 -0.878676
# HG_T_cell_M_42_years                                0.826164  0.858171
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours     -0.819801 -0.856489
# HG_activated_CD4_positive_AB_T_cell_M_20_years_... -0.972148 -0.949362
# HG_activated_CD4_positive_CD25_positive_AB_regu...  0.075763  0.129271
# HG_activated_CD8_positive_AB_T_cell_M_21_years_... -0.892005 -0.801830
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...  0.135896  0.230517
# HG_activated_T_cell_F_33_years_50_U_Interleukin... -0.555145 -0.609979
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...  0.250909  0.351066
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...  0.551242  0.582146
# HG_activated_naive_CD8_positive_AB_T_cell_nucle... -0.958493 -0.884236
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y... -0.818942 -0.810955
# HG_dendritic_cell_100_ng_LPS_2_hours                0.847500  0.882734
# HG_dendritic_cell_100_ng_LPS_30_minutes             0.959540  0.953604
# HG_dendritic_cell_100_ng_LPS_6_hours                0.950466  0.948306
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_... -0.833066 -0.889816
# HG_memory_B_cell_M_40_years                        -0.850321 -0.906223
# HG_naive_B_cell_F_39_years                         -0.865657 -0.898088
# HG_naive_B_cell_M_40_years                         -0.852451 -0.889867
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_... -0.768756 -0.865682
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...  0.829838  0.862713
# HG_stimulated_activated_effector_memory_CD8_pos...  0.793169  0.819327
# HG_stimulated_activated_memory_B_cell_M_40_year...  0.840875  0.849499
# HG_stimulated_activated_naive_B_cell_F_39_years...  0.158061  0.215208
# LCL                                                 0.690724  0.809055
# LMPP_4983                                           0.988051  0.954578
# MEP_2596                                            1.000000  0.964061
# MPP_4983                                            0.964061  1.000000
# Mono_1001                                           0.955893  0.937121
# NKcell_1001                                         0.683990  0.750022
#
#                                                     Mono_1001  NKcell_1001
# Bcell_1001                                          -0.789225    -0.485302
# CD4Tcell_1022                                       -0.769176    -0.882385
# CD8Tcell_1001                                        0.866380     0.929338
# HG_AML_IPSC_U_U                                     -0.897370    -0.605471
# HG_B_cell_M_22_years                                -0.778249    -0.624605
# HG_CD4_positive_AB_T_cell_M_20_years                -0.797189    -0.935140
# HG_CD8_positive_AB_T_cell_M_21_years                -0.871831    -0.930697
# HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U          0.965249     0.734744
# HG_K562                                             -0.447057    -0.123172
# HG_T_cell_F_21_years                                -0.865702    -0.937652
# HG_T_cell_M_42_years                                 0.869682     0.958116
# HG_activated_B_cell_M_22_years_0.5_ug_24_hours      -0.749389    -0.600510
# HG_activated_CD4_positive_AB_T_cell_M_20_years_...  -0.954699    -0.761269
# HG_activated_CD4_positive_CD25_positive_AB_regu...   0.048445     0.587125
# HG_activated_CD8_positive_AB_T_cell_M_21_years_...  -0.808952    -0.399512
# HG_activated_T_cell_F_21_years_anti_CD3_and_ant...   0.228280     0.773494
# HG_activated_T_cell_F_33_years_50_U_Interleukin...  -0.656165    -0.319651
# HG_activated_T_cell_M_43_years_anti_CD3_and_ant...   0.371602     0.827371
# HG_activated_naive_CD4_positive_AB_T_cell_M_48_...   0.562694     0.891646
# HG_activated_naive_CD8_positive_AB_T_cell_nucle...  -0.915254    -0.627976
# HG_central_memory_CD8_positive_AB_T_cell_M_36_y...  -0.903458    -0.834939
# HG_dendritic_cell_100_ng_LPS_2_hours                 0.905441     0.887422
# HG_dendritic_cell_100_ng_LPS_30_minutes              0.987867     0.779476
# HG_dendritic_cell_100_ng_LPS_6_hours                 0.984304     0.790955
# HG_effector_memory_CD8_positive_AB_T_cell_M_33_...  -0.879691    -0.933781
# HG_memory_B_cell_M_40_years                         -0.887163    -0.929680
# HG_naive_B_cell_F_39_years                          -0.897831    -0.920837
# HG_naive_B_cell_M_40_years                          -0.885882    -0.936538
# HG_naive_thymus_derived_CD4_positive_AB_T_cell_...  -0.843047    -0.806223
# HG_naive_thymus_derived_CD8_positive_AB_T_cell_...   0.903504     0.924255
# HG_stimulated_activated_effector_memory_CD8_pos...   0.869250     0.939305
# HG_stimulated_activated_memory_B_cell_M_40_year...   0.929414     0.875512
# HG_stimulated_activated_naive_B_cell_F_39_years...   0.315615     0.661270
# LCL                                                  0.733551     0.917663
# LMPP_4983                                            0.927652     0.717897
# MEP_2596                                             0.955893     0.683990
# MPP_4983                                             0.937121     0.750022
# Mono_1001                                            1.000000     0.728868
# NKcell_1001                                          0.728868     1.000000
#
# [39 rows x 39 columns]

# %%
from sklearn.decomposition import PCA
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

plt.rcParams["figure.figsize"] = (20,20)
pca = PCA()
pipe = Pipeline([('scaler', StandardScaler()), ('pca', pca)])
Xt = pipe.fit_transform(att_out_all_np)
plt.scatter(Xt[:,0], Xt[:,1])
#plt.legend(handles=plot.legend_elements()[0])
for i, txt in enumerate(file_names_all):
    plt.annotate(txt, (Xt[i,0], Xt[i,1]))
    
plt.show()

# %%
file_names_all
# Out:
# ['22rv1_prostatic_cancer',
#  '2cell_3pn_preimplant',
#  '4cell_3pn_preimplant',
#  '6tfs_epithelial',
#  '8cell_3pn_preimplant',
#  '8cell_preimplant',
#  'BE2C_cells',
#  'BIN_67_ovarian',
#  'Bcell_1001',
#  'C15_cell_line',
#  'CD34_Bone_Marrow_7291',
#  'CD34_Cord_Blood_1020',
#  'CD4Tcell_1022',
#  'CD8Tcell_1001',
#  'CLP_2596_r1',
#  'CMP_2596_r1',
#  'CRL7250_fibroblast',
#  'Ery_2596',
#  'FT190_ovarian',
#  'GMP_2596',
#  'GMP_4983_r1',
#  'H1703',
#  'HAP1',
#  'HESC',
#  'HG_A549',
#  'HG_AC16_U_U',
#  'HG_ALL_SJHBBBM5GW9_U',
#  'HG_AML_IPSC_U_U',
#  'HG_ATAC_IN_27_U_U',
#  'HG_ATL10_U_NO_TX',
#  'HG_BJ_U_DEEP_SENESCENCE',
#  'HG_B_cell_M_22_years',
#  'HG_CASKI_U_U',
#  'HG_CD4_positive_AB_T_cell_M_20_years',
#  'HG_CD8_positive_AB_T_cell_M_21_years',
#  'HG_CORD_HSC_CD34POS_D1_5HR_STIM',
#  'HG_CTL5_U_NO_TX',
#  'HG_DENDRITIC_CELL_1001_U',
#  'HG_DND_41',
#  'HG_EMBROYO_2CELL_3PN_U_U',
#  'HG_EPIDERMAL_KERATINOCYTE_CTLI_U',
#  'HG_ERYTHROBLAST_CD49DPOS_BAND3POS_DONORP5_U',
#  'HG_GM12878',
#  'HG_GM23338',
#  'HG_H1',
#  'HG_H9_U_D28',
#  'HG_HC1_IPSC_U_D22',
#  'HG_HCT116',
#  'HG_HCT116_U_BUTYRATE24',
#  'HG_HEK293',
#  'HG_HEPG2_KD_HBVNEG',
#  'HG_HG02571',
#  'HG_HG03575',
#  'HG_HL_60_U_U',
#  'HG_HMS_001_U_U',
#  'HG_HODGKINS_L1236_SH2A.B_U',
#  'HG_HPC_U_U',
#  'HG_HSC_UNK_U_UNK',
#  'HG_HT1080',
#  'HG_HT1376_U_U',
#  'HG_HUVEC',
#  'HG_HYPERTROPHIC_SCAR_U_U',
#  'HG_HepG2',
#  'HG_IMR_90_nuclear_fraction_and_unspecified_fraction',
#  'HG_IPSC_ASXL1_U',
#  'HG_ISP_CD28_THYMOCYTE_U_U',
#  'HG_Jurkat',
#  'HG_Jurkat_stim',
#  'HG_K119_U_U',
#  'HG_K562',
#  'HG_KELOID_U_U',
#  'HG_KMS27_U_U',
#  'HG_M0_MACROPHAGE_U_0_HRS',
#  'HG_MCF10A_U_U',
#  'HG_MCF_7',
#  'HG_MM1_S_U_DMSO',
#  'HG_MOLM_13_U_U',
#  'HG_MONOCYTES_1001_U',
#  'HG_MSC_U_U',
#  'HG_MSC_ZKSCAN3_KO_U',
#  'HG_MYOTUBULAR_IPSC_U_SDDF',
#  'HG_N102_U_U',
#  'HG_NCI_H929',
#  'HG_NEURON_DOPAMINERGIC_D30_IPS_07_U',
#  'HG_NEURON_GABAERGIC_D28_IPS_04_U',
#  'HG_NEURON_GLUTAMERGIC_D15_IPS_02_U',
#  'HG_NEURON_H9_CHD_KO_CR1_U',
#  'HG_NK_CELL_J4_D1',
#  'HG_NPC_D1_U',
#  'HG_PANCREATIC_ISLET_ISL6_HIGH_DEX',
#  'HG_PC_3',
#  'HG_PDCS_1001_U',
#  'HG_PLASMABLASTS_1001_U',
#  'HG_Panc1',
#  'HG_RETINA_HU8_U',
#  'HG_RWPE2',
#  'HG_Right_ventricle_myocardium_inferior_M_60_years',
#  'HG_Right_ventricle_myocardium_superior_M_60_years',
#  'HG_SCAR_U_U',
#  'HG_SCC_090_U_U',
#  'HG_SIHA_U_U',
#  'HG_SKIN_U_U',
#  'HG_SK_N_SH',
#  'HG_SK_N_SH_6_um_all_trans_retinoic_acid_48_hours',
#  'HG_SMC_CA_1346_U',
#  'HG_SUPB15_U_U',
#  'HG_THP_1_U_U',
#  'HG_TOV21G_U_U',
#  'HG_T_cell_F_21_years',
#  'HG_T_cell_M_42_years',
#  'HG_T_helper_17_cell_M_38_years',
#  'HG_T_helper_17_cell_M_50_years',
#  'HG_U937',
#  'HG_WI38_HTERT_SENESCENT',
#  'HG_WTC11',
#  'HG_WTC_11_U_',
#  'HG_Z138_Z138_KD_DMSO',
#  'HG_activated_B_cell_M_22_years_0.5_ug_24_hours',
#  'HG_activated_CD4_positive_AB_T_cell_M_20_years_anti_CD3_and_anti_CD28_coated_beads_36_hours',
#  'HG_activated_CD4_positive_CD25_positive_AB_regulatory_T_cell_M_42_years_anti_CD3_and_anti_CD28_coated_beads_24_hours_50_U_Interleukin_2_24_hours',
#  'HG_activated_CD8_positive_AB_T_cell_M_21_years_anti_CD3_and_anti_CD28_coated_beads_36_hours',
#  'HG_activated_T_cell_F_21_years_anti_CD3_and_anti_CD28_coated_beads_72_hours_50_U_Interleukin_2_72_hours',
#  'HG_activated_T_cell_F_33_years_50_U_Interleukin_2_4_hours_anti_CD3_and_anti_CD28_coated_beads_4_hours',
#  'HG_activated_T_cell_M_43_years_anti_CD3_and_anti_CD28_coated_beads_72_hours_50_U_Interleukin_2_72_hours',
#  'HG_activated_T_helper_17_cell_M_50_years_anti_CD3_and_anti_CD28_coated_beads_72_hours_50_U_Interleukin_2_72_hours',
#  'HG_activated_naive_CD4_positive_AB_T_cell_M_48_years_anti_CD3_and_anti_CD28_coated_beads_72_hours_50_U_Interleukin_2_72_hours',
#  'HG_activated_naive_CD8_positive_AB_T_cell_nuclear_fraction_M_30_years_anti_CD3_and_anti_CD28_coated_beads_7_days_10_ng_Interleukin_2_5_days',
#  'HG_adrenal_gland_F_41_years',
#  'HG_adrenal_gland_M_54_years',
#  'HG_aorta_F_child_16_years',
#  'HG_bile_duct_F_41_years',
#  'HG_body_of_pancreas_F_51_years',
#  'HG_body_of_pancreas_M_37_years',
#  'HG_breast_epithelium_F_51_years',
#  'HG_breast_epithelium_M_54_years',
#  'HG_cardiac_septum_F_41_years',
#  'HG_central_memory_CD8_positive_AB_T_cell_M_36_years',
#  'HG_colonic_mucosa_F_41_years',
#  'HG_coronary_artery_F_51_years',
#  'HG_dendritic_cell_100_ng_LPS_2_hours',
#  'HG_dendritic_cell_100_ng_LPS_30_minutes',
#  'HG_dendritic_cell_100_ng_LPS_6_hours',
#  'HG_effector_memory_CD8_positive_AB_T_cell_M_33_years',
#  'HG_esophagus_mucosa_F_47_years',
#  'HG_esophagus_muscularis_mucosa_M_54_years',
#  'HG_esophagus_squamous_epithelium_F_51_years',
#  'HG_fallopian_tube_F_46_years',
#  'HG_fallopian_tube_F_61_years',
#  'HG_foreskin_keratinocyte_M_newborn_2_4_days',
#  'HG_from_a_donor_with_amyotrophic_lateral_sclerosis_motor_neuron',
#  'HG_gastrocnemius_medialis_F_51_years',
#  'HG_gastrocnemius_medialis_M_54_years',
#  'HG_gastroesophageal_sphincter_F_51_years',
#  'HG_heart_left_ventricle_F_42_years',
#  'HG_heart_left_ventricle_M_43_years',
#  'HG_heart_right_ventricle_F_59_years',
#  'HG_heart_right_ventricle_M_43_years',
#  'HG_jejunum_F_59_years',
#  'HG_kidney_F_47_years',
#  'HG_left_cardiac_atrium_F_42_years',
#  'HG_left_cardiac_atrium_M_40_years',
#  'HG_left_colon_F_46_years',
#  'HG_left_lobe_of_liver_F_61_years',
#  'HG_left_lung_F_child_16_years',
#  'HG_left_ventricle_myocardium_inferior_M_60_years',
#  'HG_left_ventricle_myocardium_superior_M_60_years',
#  'HG_liver_M_67_years',
#  'HG_lower_lobe_of_left_lung_M_60_years',
#  'HG_lower_lobe_of_right_lung_F_65_years',
#  'HG_lower_lobe_of_right_lung_M_60_years',
#  'HG_lung_F_47_years',
#  'HG_memory_B_cell_M_40_years',
#  'HG_mesenteric_fat_pad_M_26_years',
#  'HG_mucosa_of_descending_colon_F_61_years',
#  'HG_mucosa_of_descending_colon_M_26_years',
#  'HG_mucosa_of_gallbladder_F_child_16_years',
#  'HG_mucosa_of_urinary_bladder_F_47_years',
#  'HG_mucosa_of_urinary_bladder_M_26_years',
#  'HG_naive_B_cell_F_39_years',
#  'HG_naive_B_cell_M_40_years',
#  'HG_naive_thymus_derived_CD4_positive_AB_T_cell_M_48_years',
#  'HG_naive_thymus_derived_CD8_positive_AB_T_cell_M_42_years',
#  'HG_natural_killer_cell_F_41_years',
#  'HG_natural_killer_cell_F_41_years_100_ng_Interleukin_18_72_hours_100_ng_Interleukin_12_subunit_beta_72_hours_100_ng_Interleukin_15_72_hours_100_ng_Interleukin_12_subunit_alpha_72_hours',
#  'HG_natural_killer_cell_M_47_years',
#  'HG_natural_killer_cell_M_47_years_100_ng_Interleukin_12_subunit_alpha_72_hours_100_ng_Interleukin_15_72_hours_100_ng_Interleukin_12_subunit_beta_72_hours_100_ng_Interleukin_18_72_hours',
#  'HG_omental_fat_pad_F_51_years',
#  'HG_ovary_F_59_years',
#  'HG_ovary_F_child_16_years',
#  'HG_pancreas_F_47_years',
#  'HG_pancreas_F_child_16_years',
#  'HG_peyers_patch_F_53_years',
#  'HG_posterior_vena_cava_F_child_16_years',
#  'HG_posterior_vena_cava_M_26_years',
#  'HG_prostate_gland_M_54_years',
#  'HG_psoas_muscle_F_41_years',
#  'HG_psoas_muscle_F_child_16_years',
#  'HG_right_atrium_auricular_region_F_51_years',
#  'HG_right_cardiac_atrium_F_46_years',
#  'HG_right_cardiac_atrium_M_60_years',
#  'HG_right_lobe_of_liver_F_child_16_years',
#  'HG_right_lobe_of_liver_M_40_years',
#  'HG_sciatic_nerve_F_41_years',
#  'HG_sciatic_nerve_M_26_years',
#  'HG_sigmoid_colon_F_51_years',
#  'HG_sigmoid_colon_M_54_years',
#  'HG_spleen_F_61_years',
#  'HG_spleen_M_26_years',
#  'HG_stimulated_activated_effector_memory_CD8_positive_AB_T_cell_M_33_years_100_ng_Interleukin_12_subunit_alpha_72_hours_100_ng_Interleukin_12_subunit_beta_72_hours_anti_CD3_and_anti_CD28_coated_beads_72_hours',
#  'HG_stimulated_activated_memory_B_cell_M_40_years_10_ug_anti_IgM_72_hours_1_ug_anti_CD40_72_hours_100_ng_Interleukin_4_72_hours',
#  'HG_stimulated_activated_naive_B_cell_F_39_years_1_ug_anti_CD40_72_hours_10_ug_anti_IgM_72_hours_100_ng_Interleukin_4_72_hours',
#  'HG_stomach_F_53_years',
#  'HG_stomach_M_54_years',
#  'HG_subcutaneous_adipose_F_53_years',
#  'HG_testis_M_37_years',
#  'HG_thoracic_aorta_M_54_years',
#  'HG_thyroid_gland_F_51_years',
#  'HG_thyroid_gland_M_54_years',
#  'HG_tibial_artery_M_54_years',
#  'HG_tibial_nerve_F_51_years',
#  'HG_transverse_colon_F_51_years',
#  'HG_transverse_colon_M_54_years',
#  'HG_upper_lobe_of_left_lung_F_61_years',
#  'HG_upper_lobe_of_left_lung_M_60_years',
#  'HG_upper_lobe_of_right_lung_M_60_years',
#  'HG_ureter_F_47_years',
#  'HG_uterus_F_46_years',
#  'HG_uterus_F_59_years',
#  'HSC_2596_r1',
#  'LCL',
#  'LMPP_4983',
#  'MEP_2596',
#  'MPP_4983',
#  'Mono_1001',
#  'NKcell_1001',
#  'RUES',
#  'RWPE1',
#  'SKmel147',
#  'T98G_gbm_cell_line',
#  'aaec_bronchial_eptihelium',
#  'adipocyte_stem_cell',
#  'aska',
#  'cartilage_normal',
#  'chordoma',
#  'corneal_epithelium',
#  'coronary_artery_sm',
#  'embryonic_liver_cell',
#  'embryonic_lung_cell',
#  'endometrial_stromal',
#  'fibroblast_other',
#  'gbm_stem_cell',
#  'gist_t1',
#  'h1_embryonic',
#  'hela_cervical_adenocarcinoma',
#  'hes_to_pancreatic_endoderm',
#  'hesc_ucla',
#  'hl60_cells',
#  'icm_preimplant',
#  'ipsc_forebrain_neurons',
#  'lcb_melanoma',
#  'lung_epithelial_normal',
#  'neuroblastoma_kelly',
#  'ngp_neuroblastoma',
#  'nucleus_accumbens_brain',
#  'pfc_brain',
#  'prostate_cancer_epithelium',
#  'prostate_normal',
#  'shep_neuroblastoma_bone_marrow',
#  'sirt_6.2_7',
#  'skin_caid_syndrome',
#  'skin_line_normal',
#  'synovial_sarcoma',
#  't24t_fl3_bladder_carcinoma',
#  't47d',
#  'tcells_yellow_fever',
#  'u2os',
#  'uch2_chordoma']

# %%
# Libraries
import seaborn as sns
import pandas as pd
from matplotlib import pyplot as plt
 
# Data set
url = 'https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/mtcars.csv'
df = pd.read_csv(url)
df = df.set_index('model') 
 
# plot with correlation distance
sns.clustermap(df, metric="correlation", standard_scale=1)

# %%
df
# Out:
#                       mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# model
# Mazda RX4            21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# Mazda RX4 Wag        21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# Datsun 710           22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# Hornet 4 Drive       21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# Hornet Sportabout    18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
# Valiant              18.1    6  225.0  105  2.76  3.460  20.22   1   0     3
# Duster 360           14.3    8  360.0  245  3.21  3.570  15.84   0   0     3
# Merc 240D            24.4    4  146.7   62  3.69  3.190  20.00   1   0     4
# Merc 230             22.8    4  140.8   95  3.92  3.150  22.90   1   0     4
# Merc 280             19.2    6  167.6  123  3.92  3.440  18.30   1   0     4
# Merc 280C            17.8    6  167.6  123  3.92  3.440  18.90   1   0     4
# Merc 450SE           16.4    8  275.8  180  3.07  4.070  17.40   0   0     3
# Merc 450SL           17.3    8  275.8  180  3.07  3.730  17.60   0   0     3
# Merc 450SLC          15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
# Cadillac Fleetwood   10.4    8  472.0  205  2.93  5.250  17.98   0   0     3
# Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   0     3
# Chrysler Imperial    14.7    8  440.0  230  3.23  5.345  17.42   0   0     3
# Fiat 128             32.4    4   78.7   66  4.08  2.200  19.47   1   1     4
# Honda Civic          30.4    4   75.7   52  4.93  1.615  18.52   1   1     4
# Toyota Corolla       33.9    4   71.1   65  4.22  1.835  19.90   1   1     4
# Toyota Corona        21.5    4  120.1   97  3.70  2.465  20.01   1   0     3
# Dodge Challenger     15.5    8  318.0  150  2.76  3.520  16.87   0   0     3
# AMC Javelin          15.2    8  304.0  150  3.15  3.435  17.30   0   0     3
# Camaro Z28           13.3    8  350.0  245  3.73  3.840  15.41   0   0     3
# Pontiac Firebird     19.2    8  400.0  175  3.08  3.845  17.05   0   0     3
# Fiat X1-9            27.3    4   79.0   66  4.08  1.935  18.90   1   1     4
# Porsche 914-2        26.0    4  120.3   91  4.43  2.140  16.70   0   1     5
# Lotus Europa         30.4    4   95.1  113  3.77  1.513  16.90   1   1     5
# Ford Pantera L       15.8    8  351.0  264  4.22  3.170  14.50   0   1     5
# Ferrari Dino         19.7    6  145.0  175  3.62  2.770  15.50   0   1     5
# Maserati Bora        15.0    8  301.0  335  3.54  3.570  14.60   0   1     5
# Volvo 142E           21.4    4  121.0  109  4.11  2.780  18.60   1   1     4
#
#                      carb
# model
# Mazda RX4               4
# Mazda RX4 Wag           4
# Datsun 710              1
# Hornet 4 Drive          1
# Hornet Sportabout       2
# Valiant                 1
# Duster 360              4
# Merc 240D               2
# Merc 230                2
# Merc 280                4
# Merc 280C               4
# Merc 450SE              3
# Merc 450SL              3
# Merc 450SLC             3
# Cadillac Fleetwood      4
# Lincoln Continental     4
# Chrysler Imperial       4
# Fiat 128                1
# Honda Civic             2
# Toyota Corolla          1
# Toyota Corona           1
# Dodge Challenger        2
# AMC Javelin             2
# Camaro Z28              4
# Pontiac Firebird        2
# Fiat X1-9               1
# Porsche 914-2           2
# Lotus Europa            2
# Ford Pantera L          4
# Ferrari Dino            6
# Maserati Bora           8
# Volvo 142E              2

# %%
s
