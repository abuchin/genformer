# %%
library(dplyr)
library(ggplot2)
library(data.table)

# %%
metadata <- read.table('QTLbase_v2_download_meta_info.txt',sep='\t',header=TRUE)
caQTLs <- read.table('caQTL.txt',sep='\t',header=TRUE)

# %%
caQTLs <- merge(caQTLs,metadata,by.x = c("Sourceid"))
#caQTLs <- select(caQTLs, SNP_chr,SNP_pos_hg38,SNP_pos_hg38+1, )

# %%
colnames(caQTLs)
# Out:
#  [1] "Sourceid"         "SNP_chr"          "SNP_pos_hg19"     "SNP_pos_hg38"
#  [5] "Mapped_gene"      "Trait_chr"        "Trait_start_hg19" "Trait_end_hg19"
#  [9] "Trait_start_hg38" "Trait_end_hg38"   "Pvalue"           "PMID"
# [13] "xQTL"             "Tissue"           "Population"       "Sample_size"
# [17] "Journal"          "Year"             "Genome"           "Describe"
# [21] "Title"            "Reduced.WGS"

# %%
caQTLs
# Out:
#        SNP_chr SNP_pos_hg19 SNP_pos_hg38 Mapped_gene   Trait_chr
# 1      chr1     811236       875856      FAM41C        chr1
# 2      chr1     856583       921203                    chr1
# 3      chr1     912049       976669      PERM1         chr1
# 4      chr1     911595       976215      PERM1         chr1
# 5      chr1     914940       979560      PERM1         chr1
# 6      chr1     973668      1038288      AGRN          chr1
# 7      chr1     977330      1041950      AGRN          chr1
# 8      chr1     987200      1051820      AGRN          chr1
# 9      chr1     994717      1059337                    chr1
# 10     chr1     995311      1059931      AL390719.1    chr1
# 11     chr1    1001177      1065797      AL390719.1    chr1
# 12     chr1    1011561      1076181                    chr1
# 13     chr1    1074147      1138767      LINC01342     chr1
# 14     chr1    1184244      1248864                    chr1
# 15     chr1    1186502      1251122      AL162741.1    chr1
# ...
